# %% [markdown]
# ## Variance : Amount of spread values

# %%
import numpy as np
data = [6,7,8,9,10,11,12]
variance = np.var(data)
print(variance)
# Out:
# 4.0

# %% [markdown]
# # Standard Deviation : Amount of spread values in original units

# %%
data = [2,3,4,6,7,8,10,32]
std = np.std(data)
print(std)
# Out:
# 9.041570660012562
